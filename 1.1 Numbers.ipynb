# %% [markdown]
# ## отримати внутрішнє представлення
# Цілого числа без знаку в однобайтовій комірці пам’яті.
# Для запису цілого числа без знаку досить перевести його в
# двійкову  систему  числення  і  при  необхідності  доповнити
# результат зліва незначущими нулями [2, 3].
# Додатковий  код  цілого  додатнього  числа  збігається  з  його
# прямим кодом. Для його отримання необхідно:
# 1. Перевести число N в двійкову систему числення.
# 2.  Отриманий  результат  доповнити  зліва  незначущими
# нулями до k розрядів.
# 3.  При  необхідності  перевести  число  в  стислу
# шістнадцяткову форму.

# %%
2 ** 6
# Out:
# 64

# %% [markdown]
# # Update number from 2 or 8 Base namber sistem to 10 Base sistem

# %%
primarybase = 2
number = 11001011
newbase = 10
total_decimal = 0  # 1. Створюємо змінну для накопичення суми
number_list = [int(d) for d in str(number)] # Create a list of integers
number_list.reverse()
print(number_list)
while len(number_list) > 0:
    digit = number_list.pop()
    power = len(number_list)
    decimal_value = digit * (primarybase ** power)
    total_decimal += decimal_value # 2. Додаємо до підсумку
    print(f"number {number} in base {base} is {total_decimal}")
# Out:
# [1, 1, 0, 1, 0, 0, 1, 1]
# number 11001011 in base 10 is 128
# number 11001011 in base 10 is 192
# number 11001011 in base 10 is 192
# number 11001011 in base 10 is 192
# number 11001011 in base 10 is 200
# number 11001011 in base 10 is 200
# number 11001011 in base 10 is 202
# number 11001011 in base 10 is 203

# %% [markdown]
# 1.1. Ділення з цілим результатом та отримання залишку, до отримання частки, що дорівнює нулю

# %%
''' to get whole and remainder from division number by new base '''
primarybase = 10 # base of the number system
number = 15
newbase = 2 # base of the number system
''' One-time division using divmod function '''
print(f"One-time division of number {number} by new base {newbase}:")
whole, remainder = divmod(number, newbase)
whole, remainder
# Out:
# One-time division of number 15 by new base 2:
# (7, 1)

# %%
''' the same as divmod but with operators '''
primarybase = 10 # base of the number system
number = 15
newbase = 2 # base of the number system
''' One-time division using operators // and % '''
print(f"One-time division of number {number} by new base {newbase}:")
whole = number // newbase
remainder = number % newbase
whole, remainder
# Out:
# One-time division of number 15 by new base 2:
# (7, 1)

# %% [markdown]
# 1.2. Функція послідовного ділення

# %%
primarybase = 10 # base of the number system
number = 203
newbase = 2  # base of the number system
''' The function of successive division using the operators % and // '''
print(f"Successive division number {number} on {newbase}:")
while number > 0:
    number % newbase
    print(f'remainder = {number % newbase}')
    number = number // newbase
else:
    print("FINISH")
# Out:
# Successive division number 203 on 2:
# remainder = 1
# remainder = 1
# remainder = 0
# remainder = 1
# remainder = 0
# remainder = 0
# remainder = 1
# remainder = 1
# FINISH

# %%
primarybase = 10 # base of the number system
number = 203
newbase = 2 # base of the number system
''' The function of successive division using the divmod function '''
divisor = newbase

print(f"Successive division number {number} on {divisor}:")
while number > 0:
    number, remainder = divmod(number, divisor)
    print(f"remainder: {remainder}")
print("FINISH")
# Out:
# Successive division number 203 on 2:
# remainder: 1
# remainder: 1
# remainder: 0
# remainder: 1
# remainder: 0
# remainder: 0
# remainder: 1
# remainder: 1
# FINISH

# %% [markdown]
# 1.3. Послідовність залишків від ділення, починаючи з останнього

# %%
primarybase = 10 # base of the number system
number = 203
newbase = 2   # base of the number system
remainders = []    # list to store remainders
'''if primarybase is > newbase'''  
while number > 0:
    number % newbase   # compute remainder
    remainders.append(number % newbase)    # store remainder
    print(f"remainder = {number % newbase}")
    number = number // newbase  # update number to the quotient
remainders.reverse()   # reverse the list to get correct order
remainders
# Out:
# remainder = 1
# remainder = 1
# remainder = 0
# remainder = 1
# remainder = 0
# remainder = 0
# remainder = 1
# remainder = 1
# [1, 1, 0, 0, 1, 0, 1, 1]

# %%
primarybase = 10
number = 203
newbase = 2
remainders = [] # list to store remainders

# successive division
# whole, remainder = divmod(number, divisor)
""" if number is whole and number > 0 and primarybase > newbase: """
while number > 0:
    divisor = newbase # base of the number system
    number, remainder = divmod(number, divisor) # compute remainder and update number to the quotient
    remainders.append(remainder)   # store remainder
    print(f"remainders = {remainders}")
remainders.reverse() # reverse the list to get correct order
print(f"number in base {divisor}: {remainders}")
# Out:
# remainders = [1]
# remainders = [1, 1]
# remainders = [1, 1, 0]
# remainders = [1, 1, 0, 1]
# remainders = [1, 1, 0, 1, 0]
# remainders = [1, 1, 0, 1, 0, 0]
# remainders = [1, 1, 0, 1, 0, 0, 1]
# remainders = [1, 1, 0, 1, 0, 0, 1, 1]
# number in base 2: [1, 1, 0, 0, 1, 0, 1, 1]

# %%
primarybase = 2
number = 11001011
newbase = 10
""" if number is whole and number > 0 and primarybase < newbase: """
total_decimal = 0  # 1. Створюємо змінну для накопичення суми
number_list = [int(d) for d in str(number)] # Create a list of integers
number_list.reverse()
print(number_list)
while len(number_list) > 0:
    digit = number_list.pop()  # Get the last digit
    power = len(number_list)
    decimal_value = digit * (primarybase ** power)
    total_decimal += decimal_value # 2. Додаємо до підсумку
    print(f"number {number} in base {newbase} is {total_decimal}")
# Out:
# [1, 1, 0, 1, 0, 0, 1, 1]
# number 11001011 in base 10 is 128
# number 11001011 in base 10 is 192
# number 11001011 in base 10 is 192
# number 11001011 in base 10 is 192
# number 11001011 in base 10 is 200
# number 11001011 in base 10 is 200
# number 11001011 in base 10 is 202
# number 11001011 in base 10 is 203

# %%
''' if number is whole and number > 0 '''
primarybase = 10
number = 203
newbase = 2
remainders = [] # list to store remainders
if primarybase > newbase:
    '''Function of successive division using the divmod function '''
    while number > 0:
        divisor = newbase # base of the number system
        number, remainder = divmod(number, divisor) # compute remainder and update number to the quotient
        remainders.append(remainder)   # store remainder
        print(f"remainders = {remainders}")
    remainders.reverse() # reverse the list to get correct order
    print(f"number in base {divisor}: {remainders}")
else:   # if primarybase < newbase
    total_decimal = 0  # 1. Створюємо змінну для накопичення суми
    number_list = [int(d) for d in str(number)] # Create a list of integers
    number_list.reverse()
    print(number_list)
    while len(number_list) > 0:
        digit = number_list.pop()  # Get the last digit
        power = len(number_list)
        decimal_value = digit * (primarybase ** power)
        total_decimal += decimal_value # 2. Додаємо до підсумку
        print(f"number {number} in base {newbase} is {total_decimal}")
# Out:
# remainders = [1]
# remainders = [1, 1]
# remainders = [1, 1, 0]
# remainders = [1, 1, 0, 1]
# remainders = [1, 1, 0, 1, 0]
# remainders = [1, 1, 0, 1, 0, 0]
# remainders = [1, 1, 0, 1, 0, 0, 1]
# remainders = [1, 1, 0, 1, 0, 0, 1, 1]
# numberin base 2: [1, 1, 0, 0, 1, 0, 1, 1]

# %% [markdown]
# 2. Отриманий  результат  доповнити  зліва  незначущими
# нулями до k розрядів.

# %% [markdown]
# ## отримати внутрішнє представлення
# 1. Цілого числа без знаку в однобайтовій комірці пам’яті.

# %% [markdown]
# ## отримати внутрішнє представлення
# 2. Цілого  числа  без  знаку в  2-х  байтовій  комірці.  Записати відповідь у 16-ій формі.

# %% [markdown]
# ## отримати внутрішнє представлення
# 3. Цілого  числа  зі  знаком  в  2-х  байтовій  комірці.  Записати відповідь у 16-ій формі.

# %% [markdown]
# ## отримати внутрішнє представлення
# 4. Представити  число  в  двійковій  системі  числення  в експоненційному нормалізованому вигляді
