# %%
x = 123
y = None
type(y)
# Out:
# NoneType

# %%
print(y)
# Out:
# None

# %%
z = (2 + 2 == 5)
z
# Out:
# False

# %%
z = (2 + 2 == 4)
z
# Out:
# True

# %%
type(z)
# Out:
# bool

# %%
123 == None
# Out:
# False

# %%
y is None
# Out:
# True

# %%
False == 0
# Out:
# True

# %%
True == 1
# Out:
# True

# %%
5 > 3
# Out:
# True

# %%
5 < 7
# Out:
# True

# %%
3 <= 5 >= 4
# Out:
# True

# %%
2 + 2 == 4 and 5 != 3
# Out:
# True

# %%
True == 1 and False == 0 and False == 0.0 # 'and' - True for all values
# Out:
# True

# %%
False != '' and [] != False and {} != False and None != False # True for all values
# Out:
# True

# %%
False == 0 or '' == False # 'or' True is one of the values
# Out:
# True

# %%
None not in [0, '', [], {}, False]
# Out:
# True

# %%
1 + (3 > 2)  # True is treated as 1
# Out:
# 2

# %%
1+(3>7) # False is treated as 0
# Out:
# 1

# %%
x = 0
print(-5 < x < 5)
# Out:
# True

# %%
ord('L')
# Out:
# 76

# %%
'a' in 'abc'
# Out:
# True

# %%
'A' in 'abc'
# Out:
# False

# %%
'' in 'abc' # '' always is in any string
# Out:
# True
