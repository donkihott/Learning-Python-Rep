# %%
x = 123
y = None
type(y)
# Out:
# NoneType

# %%
print(y)
# Out:
# None

# %%
z = (2 + 2 == 5)
z
# Out:
# False

# %%
z = (2 + 2 == 4)
z
# Out:
# True

# %%
type(z)
# Out:
# bool

# %%
123 == None
# Out:
# False

# %%
y is None
# Out:
# True
