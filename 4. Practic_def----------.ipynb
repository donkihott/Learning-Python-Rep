# %% [markdown]
# # ToDO!!!!!!!!!! art. 166 Programing_Basics-Python-Part-1

# %% [markdown]
# 1.  Числа m та k (3≤k≤10) вводяться з клавіатури.
# 2. Згенерувати та вивести  на  екран  m  цілих (дійсних) випадкових  чисел  з проміжку,  вказаному  у  пункті  а.
# 3. Bиведення  на  екран здійснювати по k чисел у рядку.

# %%
# частніе случаи:
# - Len не кратно к (10, 3)
# - m < k (дополнить лист к, не печатать остальніе)
# - вводится несоответствующие числа м и к

m = int(input('Enter total number of numbers (from 3 to 10)'))
k = int(input('Enter the number of numbers in a row ( from 3 to 10)'))
print(m, k)
import random
lst = []
for i in range(0, m):
    lst.append(random.randrange(3, 11)) # create a list of m numbers

print(lst[0:k])     # from first to k-element
print(lst[k:2 * k]) # from k-element in k-number elements
print(lst[k * 2:m]) # rest elements (if they are?)
    

print('list of m numbers:', lst)


    

 #   print(random.sample(lst, k))
# Out:
# 3 5
# [5, 8, 6]
# []
# []
# list of m numbers: [5, 8, 6]
